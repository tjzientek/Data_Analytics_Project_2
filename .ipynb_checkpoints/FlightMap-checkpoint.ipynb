# %%
import requests
import json
import pandas as pd
import time
from config import username, api_key

# %%
baseurl = f"http://{username}:{api_key}@flightxml.flightaware.com/json/FlightXML2/"
addurl = f"DecodeFlightRoute?faFlightID=AAL745-1534829157-airline-0092"

fxmlurl = baseurl + addurl
    
response = requests.get(fxmlurl).json()

# %%
#response = requests.get(fxmlurl).json()
#print(response)
print(json.dumps(response.DecodeFlightRouteResult, indent=4, sort_keys=True))
# Out:
# {
#     "DecodeFlightRouteResult": {
#         "data": [
#             {
#                 "latitude": 41.297078,
#                 "longitude": 2.078464,
#                 "name": "LEBL",
#                 "type": "Origin Airport"
#             },
#             {
#                 "latitude": 44.1172222,
#                 "longitude": -52.8222222,
#                 "name": "BOBTU",
#                 "type": "Waypoint (RNAV)"
#             },
#             {
#                 "latitude": 44.1666667,
#                 "longitude": -54.8833333,
#                 "name": "JAROM",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 43.15,
#                 "longitude": -67.0,
#                 "name": "BRADD",
#                 "type": "Waypoint (RNAV)"
#             },
#             {
#                 "latitude": 42.35745,
#                 "longitude": -70.9895483,
#                 "name": "BOS",
#                 "type": "VOR-DME (NAVAID)"
#             },
#             {
#                 "latitude": 42.0654861,
#                 "longitude": -72.1936389,
#                 "name": "SWALO",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 41.9410111,
#                 "longitude": -72.6885778,
#                 "name": "NELIE",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 41.4800083,
#                 "longitude": -73.3141611,
#                 "name": "GREKI",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 41.2800892,
#                 "longitude": -73.5813258,
#                 "name": "CMK",
#                 "type": "VOR-DME (NAVAID)"
#             },
#             {
#                 "latitude": 41.1526278,
#                 "longitude": -73.7968111,
#                 "name": "DUEYS",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 40.7913861,
#                 "longitude": -74.3994444,
#                 "name": "JERSY",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 40.5830419,
#                 "longitude": -74.7417911,
#                 "name": "SBJ",
#                 "type": "VOR-DME (NAVAID)"
#             },
#             {
#                 "latitude": 40.4196167,
#                 "longitude": -74.9727028,
#                 "name": "BIGGY",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 40.1307139,
#                 "longitude": -75.3767694,
#                 "name": "COPES",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 39.9180558,
#                 "longitude": -75.6708094,
#                 "name": "MXE",
#                 "type": "VOR-TAC (NAVAID)"
#             },
#             {
#                 "latitude": 39.8382056,
#                 "longitude": -75.7985889,
#                 "name": "STOEN",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 39.6020389,
#                 "longitude": -76.1735278,
#                 "name": "SACRI",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 39.4642278,
#                 "longitude": -76.3853444,
#                 "name": "MURPH",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 39.0519556,
#                 "longitude": -77.0298806,
#                 "name": "BINKS",
#                 "type": "Reporting Point"
#             },
#             {
#                 "latitude": 38.0136008,
#                 "longitude": -78.1530247,
#                 "name": "GVE",
#                 "type": "VOR-TAC (NAVAID)"
#             },
#             {
#                 "latitude": 37.2545833,
#                 "longitude": -79.2363889,
#                 "name": "LYH",
#                 "type": "VOR-TAC (NAVAID)"
#             },
#             {
#                 "latitude": 37.0178889,
#                 "longitude": -79.4360278,
#                 "name": "BEMOH",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 36.8028889,
#                 "longitude": -79.6174167,
#                 "name": "WRLLD",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 36.4976389,
#                 "longitude": -79.8723611,
#                 "name": "BLUEJ",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 36.3364167,
#                 "longitude": -80.006,
#                 "name": "BURRZ",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 36.2600556,
#                 "longitude": -80.069,
#                 "name": "SKLES",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.9866667,
#                 "longitude": -80.2933889,
#                 "name": "DENTT",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.8740278,
#                 "longitude": -80.3853333,
#                 "name": "BOOTS",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.8322778,
#                 "longitude": -80.4192778,
#                 "name": "CHSLY",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.7478056,
#                 "longitude": -80.5007778,
#                 "name": "KRISS",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.6898889,
#                 "longitude": -80.532,
#                 "name": "SLPOH",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.543,
#                 "longitude": -80.6433889,
#                 "name": "JAMGO",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.4240278,
#                 "longitude": -80.7320833,
#                 "name": "WHIZE",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.2822222,
#                 "longitude": -80.8373611,
#                 "name": "CAATT",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.0823611,
#                 "longitude": -80.8206667,
#                 "name": "EPAYE",
#                 "type": "Waypoint"
#             },
#             {
#                 "latitude": 35.21375,
#                 "longitude": -80.9490556,
#                 "name": "KCLT",
#                 "type": "Destination Airport"
#             }
#         ],
#         "next_offset": -1
#     }
# }
