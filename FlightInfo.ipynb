# %%
import requests
import json
import pandas as pd
import time
from config import username, api_key

# %%
flightNumber = 'AAL1618'

# %%
baseurl = f"http://{username}:{api_key}@flightxml.flightaware.com/json/FlightXML2/"

addurl = f"FlightInfo?ident={flightNumber}&howMany=15"

fxmlurl = baseurl + addurl

# %%
response = requests.get(fxmlurl).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "FlightInfoResult": {
#         "flights": [
#             {
#                 "actualarrivaltime": 0,
#                 "actualdeparturetime": 0,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1536619800,
#                 "filed_airspeed_kts": 325,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 0,
#                 "filed_departuretime": 1536610800,
#                 "filed_ete": "02:30:00",
#                 "filed_time": 1536384331,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": ""
#             },
#             {
#                 "actualarrivaltime": 0,
#                 "actualdeparturetime": 0,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1536533400,
#                 "filed_airspeed_kts": 325,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 0,
#                 "filed_departuretime": 1536524400,
#                 "filed_ete": "02:30:00",
#                 "filed_time": 1536297968,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": ""
#             },
#             {
#                 "actualarrivaltime": 0,
#                 "actualdeparturetime": 0,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1536446880,
#                 "filed_airspeed_kts": 458,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 360,
#                 "filed_departuretime": 1536438000,
#                 "filed_ete": "02:16:00",
#                 "filed_time": 1536211578,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "BOBZY3 BNA LIT MEEOW FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1536366443,
#                 "actualdeparturetime": 1536357695,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1536366443,
#                 "filed_airspeed_kts": 457,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 360,
#                 "filed_departuretime": 1536351600,
#                 "filed_ete": "02:13:00",
#                 "filed_time": 1536125139,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "ESTRR3 IPTAY CHOPZ ATL VUZ J52 SQS YUYUN BEREE1"
#             },
#             {
#                 "actualarrivaltime": 1536282360,
#                 "actualdeparturetime": 1536274443,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1536282360,
#                 "filed_airspeed_kts": 450,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 380,
#                 "filed_departuretime": 1536265200,
#                 "filed_ete": "02:06:00",
#                 "filed_time": 1536038748,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "ESTRR3 IPTAY CHOPZ ATL VUZ Q30 SQS YUYUN WHINY4"
#             },
#             {
#                 "actualarrivaltime": 1536188200,
#                 "actualdeparturetime": 1536179850,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1536188200,
#                 "filed_airspeed_kts": 436,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 300,
#                 "filed_departuretime": 1536178800,
#                 "filed_ete": "02:06:00",
#                 "filed_time": 1535952364,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "BOBZY3 BNA LIT MEEOW FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1536100464,
#                 "actualdeparturetime": 1536092466,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1536100464,
#                 "filed_airspeed_kts": 442,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 340,
#                 "filed_departuretime": 1536092400,
#                 "filed_ete": "02:01:00",
#                 "filed_time": 1536093931,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "BOBZY BRAYN GQO J118 MEM LIT FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1536014395,
#                 "actualdeparturetime": 1536006513,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1536014395,
#                 "filed_airspeed_kts": 455,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 360,
#                 "filed_departuretime": 1536006000,
#                 "filed_ete": "02:09:00",
#                 "filed_time": 1536007466,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "BOBZY3 BOBZY BRAYN GQO J118 MEM LIT FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1535927022,
#                 "actualdeparturetime": 1535919640,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1535927022,
#                 "filed_airspeed_kts": 454,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 380,
#                 "filed_departuretime": 1535919600,
#                 "filed_ete": "02:03:00",
#                 "filed_time": 1535920600,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "SUG105026 SPA360019 GQO J118 SALMS J118 MEM LIT FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1535840820,
#                 "actualdeparturetime": 1535833560,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1535840820,
#                 "filed_airspeed_kts": 450,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 380,
#                 "filed_departuretime": 1535833200,
#                 "filed_ete": "02:20:00",
#                 "filed_time": 1535606746,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "BOBZY3 BOBZY BRAYN GQO J118 MEM LIT FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1535762759,
#                 "actualdeparturetime": 1535755721,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1535762759,
#                 "filed_airspeed_kts": 455,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 380,
#                 "filed_departuretime": 1535746800,
#                 "filed_ete": "02:05:00",
#                 "filed_time": 1535760824,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "BOBZY3 BOBZY BRAYN GQO J118 MEM LIT FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1535668791,
#                 "actualdeparturetime": 1535661420,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1535668791,
#                 "filed_airspeed_kts": 454,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 380,
#                 "filed_departuretime": 1535660400,
#                 "filed_ete": "02:05:00",
#                 "filed_time": 1535662644,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "SPA314013 PSK225170 LIT FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1535581272,
#                 "actualdeparturetime": 1535574047,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1535581272,
#                 "filed_airspeed_kts": 448,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 380,
#                 "filed_departuretime": 1535574000,
#                 "filed_ete": "02:02:00",
#                 "filed_time": 1535575250,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "MACEY050078 LIT MEEOW FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1535494570,
#                 "actualdeparturetime": 1535487521,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1535494570,
#                 "filed_airspeed_kts": 451,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 380,
#                 "filed_departuretime": 1535487600,
#                 "filed_ete": "01:58:00",
#                 "filed_time": 1535488595,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "MACEY039056 LIT FEWWW SEEVR4"
#             },
#             {
#                 "actualarrivaltime": 1535408710,
#                 "actualdeparturetime": 1535401623,
#                 "aircrafttype": "B738",
#                 "destination": "KDFW",
#                 "destinationCity": "Dallas-Fort Worth, TX",
#                 "destinationName": "Dallas-Fort Worth Intl",
#                 "diverted": "",
#                 "estimatedarrivaltime": 1535408710,
#                 "filed_airspeed_kts": 451,
#                 "filed_airspeed_mach": "",
#                 "filed_altitude": 380,
#                 "filed_departuretime": 1535401200,
#                 "filed_ete": "02:01:00",
#                 "filed_time": 1535402706,
#                 "ident": "AAL1618",
#                 "origin": "KCLT",
#                 "originCity": "Charlotte, NC",
#                 "originName": "Charlotte/Douglas Intl",
#                 "route": "BOBZY3 BOBZY BRAYN GQO J118 MEM LIT FEWWW SEEVR4"
#             }
#         ],
#         "next_offset": 15
#     }
# }

# %%
data = response["FlightInfoResult"]
df = pd.DataFrame.from_dict(data["flights"], orient='columns')
df.head(5)
# Out:
#    actualarrivaltime  actualdeparturetime aircrafttype destination  \
# 0                  0                    0         B738        KDFW
# 1                  0                    0         B738        KDFW
# 2                  0                    0         B738        KDFW
# 3         1536366443           1536357695         B738        KDFW
# 4         1536282360           1536274443         B738        KDFW
#
#          destinationCity         destinationName diverted  \
# 0  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
# 1  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
# 2  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
# 3  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
# 4  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
#
#    estimatedarrivaltime  filed_airspeed_kts filed_airspeed_mach  \
# 0            1536619800                 325
# 1            1536533400                 325
# 2            1536446880                 458
# 3            1536366443                 457
# 4            1536282360                 450
#
#    filed_altitude  filed_departuretime filed_ete  filed_time    ident origin  \
# 0               0           1536610800  02:30:00  1536384331  AAL1618   KCLT
# 1               0           1536524400  02:30:00  1536297968  AAL1618   KCLT
# 2             360           1536438000  02:16:00  1536211578  AAL1618   KCLT
# 3             360           1536351600  02:13:00  1536125139  AAL1618   KCLT
# 4             380           1536265200  02:06:00  1536038748  AAL1618   KCLT
#
#       originCity              originName  \
# 0  Charlotte, NC  Charlotte/Douglas Intl
# 1  Charlotte, NC  Charlotte/Douglas Intl
# 2  Charlotte, NC  Charlotte/Douglas Intl
# 3  Charlotte, NC  Charlotte/Douglas Intl
# 4  Charlotte, NC  Charlotte/Douglas Intl
#
#                                              route
# 0
# 1
# 2                BOBZY3 BNA LIT MEEOW FEWWW SEEVR4
# 3  ESTRR3 IPTAY CHOPZ ATL VUZ J52 SQS YUYUN BEREE1
# 4  ESTRR3 IPTAY CHOPZ ATL VUZ Q30 SQS YUYUN WHINY4

# %%
for index, row in df.iterrows():
    
    if row["actualarrivaltime"] > 0:
        actualarrivaltime = time.strftime("%a, %d %b %Y %H:%M:%S +0000", time.localtime(row["actualarrivaltime"]))
        df.at[index, 'actualarrivaltime2'] = actualarrivaltime
    else:
        df.at[index, 'actualarrivaltime2'] = ""
    if row["actualdeparturetime"] > 0:
        actualdeparturetime = time.strftime("%a, %d %b %Y %H:%M:%S +0000", time.localtime(row["actualdeparturetime"]))
        df.at[index, 'actualdeparturetime2'] = actualdeparturetime
    else:
        df.at[index, 'actualdeparturetime2'] = ""
    
df.head(5)
# Out:
#    actualarrivaltime  actualdeparturetime aircrafttype destination  \
# 0                  0                    0         B738        KDFW
# 1                  0                    0         B738        KDFW
# 2                  0                    0         B738        KDFW
# 3         1536366443           1536357695         B738        KDFW
# 4         1536282360           1536274443         B738        KDFW
#
#          destinationCity         destinationName diverted  \
# 0  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
# 1  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
# 2  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
# 3  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
# 4  Dallas-Fort Worth, TX  Dallas-Fort Worth Intl
#
#    estimatedarrivaltime  filed_airspeed_kts filed_airspeed_mach  \
# 0            1536619800                 325
# 1            1536533400                 325
# 2            1536446880                 458
# 3            1536366443                 457
# 4            1536282360                 450
#
#                 ...                 filed_departuretime  filed_ete  \
# 0               ...                          1536610800   02:30:00
# 1               ...                          1536524400   02:30:00
# 2               ...                          1536438000   02:16:00
# 3               ...                          1536351600   02:13:00
# 4               ...                          1536265200   02:06:00
#
#    filed_time    ident origin     originCity              originName  \
# 0  1536384331  AAL1618   KCLT  Charlotte, NC  Charlotte/Douglas Intl
# 1  1536297968  AAL1618   KCLT  Charlotte, NC  Charlotte/Douglas Intl
# 2  1536211578  AAL1618   KCLT  Charlotte, NC  Charlotte/Douglas Intl
# 3  1536125139  AAL1618   KCLT  Charlotte, NC  Charlotte/Douglas Intl
# 4  1536038748  AAL1618   KCLT  Charlotte, NC  Charlotte/Douglas Intl
#
#                                              route  \
# 0
# 1
# 2                BOBZY3 BNA LIT MEEOW FEWWW SEEVR4
# 3  ESTRR3 IPTAY CHOPZ ATL VUZ J52 SQS YUYUN BEREE1
# 4  ESTRR3 IPTAY CHOPZ ATL VUZ Q30 SQS YUYUN WHINY4
#
#                 actualarrivaltime2             actualdeparturetime2
# 0
# 1
# 2
# 3  Fri, 07 Sep 2018 20:27:23 +0000  Fri, 07 Sep 2018 18:01:35 +0000
# 4  Thu, 06 Sep 2018 21:06:00 +0000  Thu, 06 Sep 2018 18:54:03 +0000
#
# [5 rows x 21 columns]
